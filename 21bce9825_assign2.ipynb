# %% [markdown]
# <a href="https://colab.research.google.com/github/smartinternz02/SI-GuidedProject-581103-1694708744/blob/main/21bce9825_assign2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Roll = 21BCE9825
Name = SAKETH RAM BOMMARAJU
AI ML
ASSIGN 2

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = sns.load_dataset("car_crashes")
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
df.plot(x="alcohol",y="ins_losses")
# Out:
# <Axes: xlabel='alcohol'>

# %%
df.plot(x="alcohol", y= "ins_losses", ms=20)
plt.grid()

# %%
plt.scatter(x=df["alcohol"], y =df["ins_losses"])
plt.xlabel("Alcohol")
plt.ylabel("Insurance Losses")
plt.title("Scatter Plot of Alcohol vs Insurance Losses")
plt.show()

# %%
plt.scatter(x=df["alcohol"], y=df["ins_losses"], color='hotpink')
plt.xlabel("Alcohol")
plt.ylabel("Insurance Losses")
plt.title("Scatter Plot")
plt.show()

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.xlabel("Alcohol")
plt.ylabel("Insurance Losses")
plt.title("Scatter Plot")
plt.bar(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.title("Scatter plot horizontal")
plt.barh(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.title("Scatter plot in pink colour")
plt.barh(x,y,color='pink')
# Out:
# <BarContainer object of 51 artists>

# %%
x = np.array(df["alcohol"])
y = np.array(df["ins_losses"])
plt.title("Scatter Plot")
plt.bar(x,y,width=0.1)
# Out:
# <BarContainer object of 51 artists>
